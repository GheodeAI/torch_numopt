# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torch_numopt
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, TensorDataset
from sklearn.datasets import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error
from train_loop import train_loop

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
n_epoch = 100

# %%
class Net(nn.Module):
    def __init__(self, input_size, device="cpu"):
        super().__init__()
        self.f1 = nn.Linear(input_size, 10, device=device)
        self.f2 = nn.Linear(10, 20, device=device)
        self.f3 = nn.Linear(20, 20, device=device)
        self.f4 = nn.Linear(20, 10, device=device)
        self.f5 = nn.Linear(10, 1, device=device)

        self.activation = nn.ReLU()
        # self.activation = nn.Sigmoid()

    def forward(self, x):
        x = self.activation(self.f1(x))
        x = self.activation(self.f2(x))
        x = self.activation(self.f3(x))
        x = self.activation(self.f4(x))
        x = self.f5(x)

        return x

# %%
# X, y = load_diabetes(return_X_y=True, scaled=False)
# X, y = make_regression(n_samples=1000, n_features=100)
X, y = make_friedman1(n_samples=1000, noise=1e-2)

X_scaler = MinMaxScaler()
X = X_scaler.fit_transform(X)
X = torch.Tensor(X).to(device)

y_scaler = MinMaxScaler()
y = y_scaler.fit_transform(y.reshape((-1, 1)))
y = torch.Tensor(y).to(device)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)

torch_data = TensorDataset(X_train, y_train)
data_loader = DataLoader(torch_data, batch_size=1000)
# Out:
# torch.Size([800, 10]) torch.Size([800, 1])
# torch.Size([200, 10]) torch.Size([200, 1])

# %%
model = Net(input_size=X.shape[1], device=device)
loss_fn = nn.MSELoss()

opt = torch_numopt.GaussNewtonLS(model=model)

model, loss_history = train_loop(
    model,
    loss_fn,
    opt,
    data_loader,
    epochs=n_epoch,
    max_patience=50
)
# Out:
# epoch:  0, loss: 0.6961719989776611
# epoch:  1, loss: 0.49210286140441895
# epoch:  2, loss: 0.20710693299770355
# epoch:  3, loss: 0.1351507157087326
# epoch:  4, loss: 0.09214840084314346
# epoch:  5, loss: 0.06074152886867523
# epoch:  6, loss: 0.04861457273364067
# epoch:  7, loss: 0.03478860855102539
# epoch:  8, loss: 0.025406869128346443
# epoch:  9, loss: 0.018811563029885292
# epoch:  10, loss: 0.01473612803965807
# Linear algebra error. torch.linalg.solve: The solver failed because the input matrix is singular.
# Fallback to lsqrs solver.
# epoch:  11, loss: 0.012701964005827904
# epoch:  12, loss: 0.0072346837259829044
# Linear algebra error. torch.linalg.solve: The solver failed because the input matrix is singular.
# Fallback to lsqrs solver.
# epoch:  13, loss: 0.005798012483865023
# epoch:  14, loss: 0.004845618735998869
# epoch:  15, loss: 0.004490697756409645
# epoch:  16, loss: 0.003259520512074232
# Linear algebra error. torch.linalg.solve: The solver failed because the input matrix is singular.
# Fallback to lsqrs solver.
# epoch:  17, loss: 0.003083496354520321
# epoch:  18, loss: 0.0029285734053701162
# epoch:  19, loss: 0.0024610613472759724
# Linear algebra error. torch.linalg.solve: The solver failed because the input matrix is singular.
# Fallback to lsqrs solver.
# epoch:  20, loss: 0.0023724976927042007
# epoch:  21, loss: 0.002293182536959648
# Linear algebra error. torch.linalg.solve: The solver failed because the input matrix is singular.
# Fallback to lsqrs solver.
# epoch:  22, loss: 0.002043065382167697
# epoch:  23, loss: 0.001855021808296442
# epoch:  24, loss: 0.0018540153978392482
# Linear algebra error. torch.linalg.solve: The solver failed because the input matrix is singular.
# Fallback to lsqrs solver.
# epoch:  25, loss: 0.0017376926261931658
# epoch:  26, loss: 0.001431289012543857
# Linear algebra error. torch.linalg.solve: The solver failed because the input matrix is singular.
# Fallback to lsqrs solver.
# epoch:  27, loss: 0.0013154366752132773
# epoch:  28, loss: 0.0011918899836018682
# Linear algebra error. torch.linalg.solve: The solver failed because the input matrix is singular.
# Fallback to lsqrs solver.
# epoch:
# Linear algebra error. torch.linalg.solve: The solver failed because the input matrix is singular.
# Fallback to lsqrs solver.
# epoch:  96, loss: 0.00025427938089706004
# epoch:  97, loss: 0.00025265204021707177
# Linear algebra error. torch.linalg.solve: The solver failed because the input matrix is singular.
# Fallback to lsqrs solver.
# epoch:  98, loss: 0.00025100322091020644
# epoch:  99, loss: 0.0002493502979632467

# %%
pred_train = model.forward(X_train).cpu().detach()
pred_test = model.forward(X_test).cpu().detach()
print(f"Train metrics: R2 = {r2_score(pred_train, y_train.cpu())}")
print(f"Test metrics:  R2 = {r2_score(pred_test, y_test.cpu())}")
# Out:
# Train metrics: R2 = 0.9912455795921381
# Test metrics:  R2 = 0.9610613866423756

# %%
model = Net(input_size=X.shape[1], device=device)
loss_fn = nn.MSELoss()

opt = torch_numopt.GaussNewtonLS(
    model=model,
)

model, loss_history = train_loop(
    model,
    loss_fn,
    opt,
    data_loader,
    epochs=n_epoch,
    max_patience=50
)
# Out:
# epoch:  0, loss: 0.5784922242164612
# epoch:  1, loss: 0.44299957156181335
# epoch:  2, loss: 0.3077968955039978
# epoch:  3, loss: 0.19238322973251343
# epoch:  4, loss: 0.12083074450492859
# epoch:  5, loss: 0.07299482077360153
# Linear algebra error. torch.linalg.solve: The solver failed because the input matrix is singular.
# Fallback to lsqrs solver.
# epoch:  6, loss: 0.019085103645920753
# epoch:  7, loss: 0.008534373715519905
# epoch:  8, loss: 0.0058271572925150394
# epoch:  9, loss: 0.004540430381894112
# epoch:  10, loss: 0.00386025314219296
# epoch:  11, loss: 0.003318530274555087
# epoch:  12, loss: 0.002925114007666707
# epoch:  13, loss: 0.0026303837075829506
# epoch:  14, loss: 0.002421273849904537
# epoch:  15, loss: 0.002278946340084076
# epoch:  16, loss: 0.002113169524818659
# epoch:  17, loss: 0.0020190735813230276
# epoch:  18, loss: 0.001908920588903129
# epoch:  19, loss: 0.0018053847597911954
# epoch:  20, loss: 0.0017458766233175993
# epoch:  21, loss: 0.0016725234454497695
# epoch:  22, loss: 0.0016086837276816368
# epoch:  23, loss: 0.0015442963922396302
# epoch:  24, loss: 0.0014827910345047712
# epoch:  25, loss: 0.0014076345833018422
# epoch:  26, loss: 0.0013799144653603435
# epoch:  27, loss: 0.001331058912910521
# epoch:  28, loss: 0.0013071084395051003
# epoch:  29, loss: 0.0012581831542775035
# epoch:  30, loss: 0.0012576165609061718
# epoch:  31, loss: 0.0012154788710176945
# epoch:  32, loss: 0.0012008983176201582
# epoch:  33, loss: 0.001170076080597937
# epoch:  34, loss: 0.001158045488409698
# epoch:  35, loss: 0.0011242153123021126
# epoch:  36, loss: 0.0010975972982123494
# epoch:  37, loss: 0.0010693484218791127
# epoch:  38, loss: 0.001055302214808762
# epoch:  39, loss: 0.0010486355749890208
# epoch:  40, loss: 0.00102429767139256
# epoch:  41, loss: 0.001010086270980537
# epoch:  42, loss: 0.000989871216006577
# epoch:  43, loss: 0.0009837582474574447
# epoch:  44, loss: 0.000976070761680603
# epoch:  45, loss: 0.000963633821811527
# epoch:  46, loss: 0.0009478309657424688
# epoch:  47, loss: 0.0009374425280839205
# epoch:  48, loss: 0.00091737718321383
# epoch:  49, loss: 0.0009142401977442205
# Linear algebra error. torch.linalg.solve: The solver failed because the input matrix is singular.
# Fallback to lsqrs solver.
# epoch:  50, loss: 0.0009142115013673902
# epoch:  51, loss: 0.0009048893116414547
# epoch:  52, loss: 0.0008965115412138402
# epoch:  53, loss: 0.0008804154349491
# epoch:  54, loss: 0.0008661134634166956
# epoch:  55, loss: 0.0008658480364829302
# epoch:  56, loss: 0.0008534575463272631
# Linear algebra error. torch.linalg.solve: The solver failed because the input matrix is singular.
# Fallback to lsqrs solver.
# epoch:  57, loss: 0.00084446812979877
# epoch:  58, loss: 0.0008382924715988338
# Linear algebra error. torch.linalg.solve: The solver failed because the input matrix is singular.
# Fallback to lsqrs solver.
# epoch:  59, loss: 0.000834563747048378
# epoch:  60, loss: 0.0008325776434503496
# epoch:  61, loss: 0.0008312546997331083
# epoch:  62, loss: 0.0008277071756310761
# epoch:  63, loss: 0.0008251601248048246
# Linear algebra error. torch.linalg.solve: The solver failed because the input matrix is singular.
# Fallback to lsqrs solver.
# epoch:  64, loss: 0.0008233361877501011
# epoch:  65, loss: 0.0008227413054555655
# epoch:  66, loss: 0.0008216409478336573
# epoch:  67, loss: 0.0008208562503568828
# epoch:  68, loss: 0.0008201135788112879
# epoch:  69, loss: 0.0008188094943761826
# epoch:  70, loss: 0.0008183709578588605
# epoch:  71, loss: 0.0008177182171493769
# epoch:  72, loss: 0.0008169420761987567
# epoch:  73, loss: 0.0008163249585777521
# epoch:  74, loss: 0.000815868959762156
# epoch:  75, loss: 0.0008149731438606977
# epoch:  76, loss: 0.0008144091116264462
# epoch:  77, loss: 0.0008137744734995067
# epoch:  78, loss: 0.0008131226641125977
# epoch:  79, loss: 0.0008125714957714081
# epoch:  80, loss: 0.0008120523998513818
# epoch:  81, loss: 0.0008113067015074193
# epoch:  82, loss: 0.0008108444744721055
# epoch:  83, loss: 0.000810458732303232
# epoch:  84, loss: 0.0008096275269053876
# epoch:  85, loss: 0.0008089980692602694
# epoch:  86, loss: 0.0008084628498181701
# epoch:  87, loss: 0.0008079309482127428
# epoch:  88, loss: 0.0008074024226516485
# epoch:  89, loss: 0.0008068095776252449
# Linear algebra error. torch.linalg.solve: The solver failed because the input matrix is singular.
# Fallback to lsqrs solver.
# epoch:  90, loss: 0.0008062502020038664
# epoch:  91, loss: 0.0008055503712967038
# Linear algebra error. torch.linalg.solve: The solver failed because the input matrix is singular.
# Fallback to lsqrs solver.
# epoch:  92, loss: 0.0008050606120377779
# epoch:  93, loss: 0.0008047419833019376
# epoch:  94, loss: 0.0008044492569752038
# epoch:  95, loss: 0.0008044305723160505
# epoch:  96, loss: 0.000803581322543323
# Linear algebra error. torch.linalg.solve: The solver failed because the input matrix is singular.
# Fallback to lsqrs solver.
# epoch:  97, loss: 0.0008031901088543236
# epoch:  98, loss: 0.0008025611168704927
# epoch:  99, loss: 0.0008019584347493947

# %%
pred_train = model.forward(X_train).cpu().detach()
pred_test = model.forward(X_test).cpu().detach()
print(f"Train metrics: R2 = {r2_score(pred_train, y_train.cpu())}")
print(f"Test metrics:  R2 = {r2_score(pred_test, y_test.cpu())}")
# Out:
# Train metrics: R2 = 0.9709486190949913
# Test metrics:  R2 = 0.7135081729511067
