# %%
import logging
import torch
import torch.nn as nn
import torch.optim as optim
import torch_numopt
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, TensorDataset
from sklearn.datasets import *
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_absolute_error
from train_loop import train_loop

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

logging.basicConfig(level=logging.DEBUG)
# n_epoch = 1000
n_epoch = 10

# %%
class Net(nn.Module):
    def __init__(self, input_size, device="cpu"):
        super().__init__()
        self.f1 = nn.Linear(input_size, 10, device=device)
        self.f2 = nn.Linear(10, 20, device=device)
        self.f3 = nn.Linear(20, 20, device=device)
        self.f4 = nn.Linear(20, 10, device=device)
        self.f5 = nn.Linear(10, 1, device=device)

        self.activation = nn.ReLU()
        # self.activation = nn.Sigmoid()

    def forward(self, x):
        x = self.activation(self.f1(x))
        x = self.activation(self.f2(x))
        x = self.activation(self.f3(x))
        x = self.activation(self.f4(x))
        x = self.f5(x)

        return x

# %%
# X, y = load_diabetes(return_X_y=True, scaled=False)
# X, y = make_regression(n_samples=1000, n_features=100)
X, y = make_friedman1(n_samples=1000, noise=1e-2)

X_scaler = MinMaxScaler()
X = X_scaler.fit_transform(X)
X = torch.Tensor(X).to(device)

y_scaler = MinMaxScaler()
y = y_scaler.fit_transform(y.reshape((-1, 1)))
y = torch.Tensor(y).to(device)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)

torch_data = TensorDataset(X_train, y_train)
data_loader = DataLoader(torch_data, batch_size=10000)
# Out:
# torch.Size([800, 10]) torch.Size([800, 1])
# torch.Size([200, 10]) torch.Size([200, 1])

# %%
model = Net(input_size=X.shape[1], device=device)
loss_fn = nn.MSELoss()

opt = torch_numopt.NewtonLS(model=model, lr_init=1, line_search_method="backtrack", line_search_cond="armijo")

model, loss_history = train_loop(model, loss_fn, opt, data_loader, epochs=n_epoch, max_patience=50)
# Out:
# INFO:torch_numopt.scaling_matrix_calculator:Computing the exact hessian matrix.
# INFO:torch_numopt.numerical_optimizer:Using matrix form of curvature, solving linear system...
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was 9.09888e+11, new condition number is 16345.2
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was 1.45888e+10, new condition number is 6429.51
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 40947.1
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 50901.4
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 143399
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 282427
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 933770
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 3.80841e+06
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 1.05533e+06
# /home/eugenio/anaconda3/envs/torch_numopt/lib/python3.10/logging/__init__.py:368: UserWarning: Converting a tensor with requires_grad=True to a scalar may lead to unexpected behavior.
# Consider using tensor.detach() first. (Triggered internally at /pytorch/torch/csrc/autograd/generated/python_variable_methods.cpp:836.)
#   msg = msg % self.args
# INFO:torch_numopt.line_search:Starting backtracking line search with initial guess of 1 with loss of 1.64013e+10.
# INFO:torch_numopt.line_search:Step was rejected.
# DEBUG:torch_numopt.line_search:Iteration 0, new guess is 0.1 which yielded a loss of 24.544.
# INFO:torch_numopt.line_search:Step was rejected.
# DEBUG:torch_numopt.line_search:Iteration 1, new guess is 0.01 which yielded a loss of 0.171711.
# INFO:torch_numopt.line_search:Step was accepted.
# INFO:torch_numopt.line_search:Settled into lr = 0.01.
# INFO:torch_numopt.scaling_matrix_calculator:Computing the exact hessian matrix.
# epoch:  0, loss: 0.2099999487400055
# INFO:torch_numopt.numerical_optimizer:Using matrix form of curvature, solving linear system...
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was 1.61285e+11, new condition number is 120976
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was 5.96701e+09, new condition number is 47560.5
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 385062
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 184389
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 904973
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was 2.16528e+19, new condition number is 742346
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 1.42458e+06
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 4.31365e+06
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 1.92335e+06
# INFO:torch_numopt.numerical_optimizer:Initial lr generated = 1 with method None and initial guess 1.
# INFO:torch_numopt.line_search:Starting backtracking line search with initial guess of 1 with loss of 1.45876e+09.
# INFO:torch_numopt.line_search:Step was rejected.
# DEBUG:torch_numopt.line_search:Iteration 0, new guess is 0.1 which yielded a loss of 0.856597.
# INFO:torch_numopt.line_search:Step was rejected.
# DEBUG:torch_numopt.line_search:Iteration 1, new guess is 0.01 which yielded a loss of 0.138993.
# INFO:torch_numopt.line_search:Step was accepted.
# INFO:torch_numopt.line_search:Settled into lr = 0.01.
# INFO:torch_numopt.scaling_matrix_calculator:Computing the exact hessian matrix.
# epoch:  1, loss: 0.17171108722686768
# INFO:torch_numopt.numerical_optimizer:Using matrix form of curvature, solving linear system...
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was 3.16197e+11, new condition number is 232210
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was 1.02307e+10, new condition number is 95831.6
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 837157
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 313795
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 1.61472e+06
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was 4.08664e+17, new condition number is 875926
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 1.32042e+06
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 4.15316e+06
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 2.68767e+06
# INFO:torch_numopt.numerical_optimizer:Initial lr generated = 1 with method None and initial guess 1.
# INFO:torch_numopt.line_search:Starting backtracking line search with initial guess of 1 with loss of 3.24494e+09.
# INFO:torch_numopt.line_search:Step was rejected.
# DEBUG:torch_numopt.line_search:Iteration 0, new guess is 0.1 which yielded a loss of 0.296091.
# INFO:torch_numopt.line_search:Step was rejected.
# DEBUG:torch_numopt.line_search:Iteration 1, new guess is 0.01 which yielded a loss of 0.115459.
# INFO:torch_numopt.line_search:Step was accepted.
# INFO:torch_numopt.line_search:Settled into lr = 0.01.
# INFO:torch_numopt.scaling_matrix_calculator:Computing the exact hessian matrix.
# epoch:  2, loss: 0.1389925330877304
# INFO:torch_numopt.numerical_optimizer:Using matrix form of curvature, solving linear system...
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was 1.81316e+11, new condition number is 458476
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was 1.93624e+10, new condition number is 191703
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 1.67226e+06
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 547229
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 3.3134e+06
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was 8.60746e+17, new condition number is 1.43565e+06
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 1.53672e+06
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 5.13248e+06
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 2.6685e+06
# INFO:torch_numopt.numerical_optimizer:Initial lr generated = 1 with method None and initial guess 1.
# INFO:torch_numopt.line_search:Starting backtracking line search with initial guess of 1 with loss of 4.29397e+06.
# INFO:torch_numopt.line_search:Step was rejected.
# DEBUG:torch_numopt.line_search:Iteration 0, new guess is 0.1 which yielded a loss of 0.255754.
# INFO:torch_numopt.line_search:Step was rejected.
# DEBUG:torch_numopt.line_search:Iteration 1, new guess is 0.01 which yielded a loss of 0.0950768.
# INFO:torch_numopt.line_search:Step was accepted.
# INFO:torch_numopt.line_search:Settled into lr = 0.01.
# INFO:torch_numopt.scaling_matrix_calculator:Computing the exact hessian matrix.
# epoch:  3, loss: 0.11545873433351517
# INFO:torch_numopt.numerical_optimizer:Using matrix form of curvature, solving linear system...
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was 1.98566e+11, new condition number is 723849
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was 1.47282e+09, new condition number is 299556
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 2.98234e+06
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 861817
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 5.97641e+06
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was 1.74632e+18, new condition number is 1.87595e+06
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 3.84011e+06
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 5.253e+06
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 3.73013e+06
# INFO:torch_numopt.numerical_optimizer:Initial lr generated = 1 with method None and initial guess 1.
# INFO:torch_numopt.line_search:Starting backtracking line search with initial guess of 1 with loss of 2.71333e+06.
# INFO:torch_numopt.line_search:Step was rejected.
# DEBUG:torch_numopt.line_search:Iteration 0, new guess is 0.1 which yielded a loss of 0.0360509.
# INFO:torch_numopt.line_search:Step was accepted.
# INFO:torch_numopt.line_search:Settled into lr = 0.1.
# INFO:torch_numopt.scaling_matrix_calculator:Computing the exact hessian matrix.
# epoch:  4, loss: 0.09507683664560318
# INFO:torch_numopt.numerical_optimizer:Using matrix form of curvature, solving linear system...
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was 1.38664e+13, new condition number is 3.76915e+07
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was 2.43997e+09, new condition number is 1.47328e+07
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 2.10416e+08
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 1.14702e+07
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 8.43215e+07
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 7.36199e+06
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 1.2068e+08
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 9.48136e+06
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 1.48966e+07
# INFO:torch_numopt.numerical_optimizer:Initial lr generated = 1 with method None and initial guess 1.
# INFO:torch_numopt.line_search:Starting backtracking line search with initial guess of 1 with loss of 137.486.
# INFO:torch_numopt.line_search:Step was rejected.
# DEBUG:torch_numopt.line_search:Iteration 0, new guess is 0.1 which yielded a loss of 0.0238373.
# INFO:torch_numopt.line_search:Step was accepted.
# INFO:torch_numopt.line_search:Settled into lr = 0.1.
# INFO:torch_numopt.scaling_matrix_calculator:Computing the exact hessian matrix.
# epoch:  5, loss: 0.036050859838724136
# INFO:torch_numopt.numerical_optimizer:Using matrix form of curvature, solving linear system...
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was 1.25788e+11, new condition number is 2.44294e+07
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was 6.54026e+08, new condition number is 9.30387e+06
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 7.27759e+07
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 9.51819e+06
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 7.7069e+07
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 5.58534e+06
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 1.06192e+08
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 7.36265e+06
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 1.48757e+07
# INFO:torch_numopt.numerical_optimizer:Initial lr generated = 1 with method None and initial guess 1.
# INFO:torch_numopt.line_search:Starting backtracking line search with initial guess of 1 with loss of 22.1326.
# INFO:torch_numopt.line_search:Step was rejected.
# DEBUG:torch_numopt.line_search:Iteration 0, new guess is 0.1 which yielded a loss of 0.00852276.
# INFO:torch_numopt.line_search:Step was accepted.
# INFO:torch_numopt.line_search:Settled into lr = 0.1.
# INFO:torch_numopt.scaling_matrix_calculator:Computing the exact hessian matrix.
# epoch:  6, loss: 0.023837300017476082
# INFO:torch_numopt.numerical_optimizer:Using matrix form of curvature, solving linear system...
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was 3.80418e+10, new condition number is 1.58656e+07
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was 1.2419e+09, new condition number is 6.29116e+06
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 1.24367e+08
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 1.25073e+07
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 9.11014e+07
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 6.20629e+06
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 1.13719e+08
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 7.16442e+06
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 1.91682e+07
# INFO:torch_numopt.numerical_optimizer:Initial lr generated = 1 with method None and initial guess 1.
# INFO:torch_numopt.line_search:Starting backtracking line search with initial guess of 1 with loss of 7.22779.
# INFO:torch_numopt.line_search:Step was rejected.
# DEBUG:torch_numopt.line_search:Iteration 0, new guess is 0.1 which yielded a loss of 0.00579123.
# INFO:torch_numopt.line_search:Step was accepted.
# INFO:torch_numopt.line_search:Settled into lr = 0.1.
# INFO:torch_numopt.scaling_matrix_calculator:Computing the exact hessian matrix.
# epoch:  7, loss: 0.008522764779627323
# INFO:torch_numopt.numerical_optimizer:Using matrix form of curvature, solving linear system...
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was 9.07927e+11, new condition number is 1.35959e+07
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was 1.06997e+09, new condition number is 5.50576e+06
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 1.32351e+08
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 1.71709e+07
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 8.18378e+07
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 6.15439e+06
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 5.96364e+07
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 7.15417e+06
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 1.76537e+07
# INFO:torch_numopt.numerical_optimizer:Initial lr generated = 1 with method None and initial guess 1.
# INFO:torch_numopt.line_search:Starting backtracking line search with initial guess of 1 with loss of 0.292654.
# INFO:torch_numopt.line_search:Step was rejected.
# DEBUG:torch_numopt.line_search:Iteration 0, new guess is 0.1 which yielded a loss of 0.00469939.
# INFO:torch_numopt.line_search:Step was accepted.
# INFO:torch_numopt.line_search:Settled into lr = 0.1.
# INFO:torch_numopt.scaling_matrix_calculator:Computing the exact hessian matrix.
# epoch:  8, loss: 0.005791227333247662
# INFO:torch_numopt.numerical_optimizer:Using matrix form of curvature, solving linear system...
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was 4.61487e+10, new condition number is 1.33346e+07
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was 6.46451e+09, new condition number is 5.40252e+06
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 3.33585e+08
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 2.29026e+07
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 1.09022e+08
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 6.48494e+06
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 2.07411e+08
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 7.50199e+06
# DEBUG:torch_numopt.numerical_optimizer:Numerical instability found, condition number was inf, new condition number is 1.81323e+07
# INFO:torch_numopt.numerical_optimizer:Initial lr generated = 1 with method None and initial guess 1.
# INFO:torch_numopt.line_search:Starting backtracking line search with initial guess of 1 with loss of 2.6382.
# INFO:torch_numopt.line_search:Step was rejected.
# DEBUG:torch_numopt.line_search:Iteration 0, new guess is 0.1 which yielded a loss of 0.00396821.
# INFO:torch_numopt.line_search:Step was accepted.
# INFO:torch_numopt.line_search:Settled into lr = 0.1.
# epoch:  9, loss: 0.004699392709881067

# %%
model.eval()
pred_train = model.forward(X_train).cpu().detach()
pred_test = model.forward(X_test).cpu().detach()
print(f"Train metrics: R2 = {r2_score(pred_train, y_train.cpu())}")
print(f"Test metrics:  R2 = {r2_score(pred_test, y_test.cpu())}")
# Out:
# Train metrics: R2 = -0.729893468386652
# Test metrics:  R2 = -0.500376114153902

# %%
model = Net(input_size=X.shape[1], device=device)
loss_fn = nn.MSELoss()

opt = torch_numopt.NewtonLS(model=model, lr_init=0.1, line_search_method="interpolate", line_search_cond="armijo")

model, loss_history = train_loop(model, loss_fn, opt, data_loader, epochs=n_epoch, max_patience=50)
# Out:
# epoch:  0, loss: 0.25481894612312317
# epoch:  1, loss: 0.2469928115606308
# epoch:  2, loss: 0.12801200151443481
# epoch:  3, loss: 0.08527552336454391
# epoch:  4, loss: 0.07564933598041534
# epoch:  5, loss: 0.06630689650774002
# epoch:  6, loss: 0.04857584834098816
# epoch:  7, loss: 0.026997730135917664
# epoch:  8, loss: 0.022027362138032913
# epoch:  9, loss: 0.016636379063129425

# %%
model.eval()
pred_train = model.forward(X_train).cpu().detach()
pred_test = model.forward(X_test).cpu().detach()
print(f"Train metrics: R2 = {r2_score(pred_train, y_train.cpu())}")
print(f"Test metrics:  R2 = {r2_score(pred_test, y_test.cpu())}")
# Out:
# Train metrics: R2 = 0.12962590413674702
# Test metrics:  R2 = -0.29715921293459324

# %%
model = Net(input_size=X.shape[1], device=device)
loss_fn = nn.MSELoss()

opt = torch_numopt.NewtonLS(model=model, lr_init=1, line_search_method="bisect", line_search_cond="armijo", max_iter=100)

model, loss_history = train_loop(model, loss_fn, opt, data_loader, epochs=n_epoch, max_patience=50)
# Out:
# epoch:  0, loss: 0.1506408154964447
# epoch:  1, loss: 0.13930641114711761
# epoch:  2, loss: 0.03202084079384804
# epoch:  3, loss: 0.06141572445631027
# epoch:  4, loss: 0.036311808973550797
# epoch:  5, loss: 0.022008847445249557
# epoch:  6, loss: 0.011731993407011032
# epoch:  7, loss: 0.009662913158535957
# epoch:  8, loss: 0.008040920831263065
# epoch:  9, loss: 0.0069994209334254265

# %%
model.eval()
pred_train = model.forward(X_train).cpu().detach()
pred_test = model.forward(X_test).cpu().detach()
print(f"Train metrics: R2 = {r2_score(pred_train, y_train.cpu())}")
print(f"Test metrics:  R2 = {r2_score(pred_test, y_test.cpu())}")
# Out:
# Train metrics: R2 = 0.6952008668015617
# Test metrics:  R2 = 0.5624886972187038
